# %%
# !pip install ucimlrepo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ucimlrepo in c:\users\user\appdata\roaming\python\python311\site-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from ucimlrepo) (2.2.3)
# Requirement already satisfied: certifi>=2020.12.5 in c:\users\user\appdata\roaming\python\python311\site-packages (from ucimlrepo) (2023.5.7)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\user\appdata\roaming\python\python311\site-packages (from pandas>=1.0.0->ucimlrepo) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\new folder\new folder\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in e:\new folder\new folder\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in e:\new folder\new folder\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2023.3)
# Requirement already satisfied: six>=1.5 in e:\new folder\new folder\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.16.0)

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
car_evaluation = fetch_ucirepo(id=19) 
  
# data (as pandas dataframes) 
X = car_evaluation.data.features 
y = car_evaluation.data.targets 
  
# metadata 
print(car_evaluation.metadata) 
  
# variable information 
print(car_evaluation.variables)
# Out:
# {'uci_id': 19, 'name': 'Car Evaluation', 'repository_url': 'https://archive.ics.uci.edu/dataset/19/car+evaluation', 'data_url': 'https://archive.ics.uci.edu/static/public/19/data.csv', 'abstract': 'Derived from simple hierarchical decision model, this database may be useful for testing constructive induction and structure discovery methods.', 'area': 'Other', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 1728, 'num_features': 6, 'feature_types': ['Categorical'], 'demographics': [], 'target_col': ['class'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1988, 'last_updated': 'Thu Aug 10 2023', 'dataset_doi': '10.24432/C5JP48', 'creators': ['Marko Bohanec'], 'intro_paper': {'ID': 249, 'type': 'NATIVE', 'title': 'Knowledge acquisition and explanation for multi-attribute decision making', 'authors': 'M. Bohanec, V. Rajkovič', 'venue': '8th Intl Workshop on Expert Systems and their Applications, Avignon, France', 'year': 1988, 'journal': None, 'DOI': None, 'URL': 'https://www.semanticscholar.org/paper/KNOWLEDGE-ACQUISITION-AND-EXPLANATION-FOR-DECISION-Bohanec-Rajkovi%C4%8D/8bab443ae322ff47c3e609272bd93fd4650555bc', 'sha': None, 'corpus': None, 'arxiv': None, 'mag': None, 'acl': None, 'pmid': None, 'pmcid': None}, 'additional_info': {'summary': 'Car Evaluation Database was derived from a simple hierarchical decision model originally developed for the demonstration of DEX, M. Bohanec, V. Rajkovic: Expert system for decision making. Sistemica 1(1), pp. 145-157, 1990.). The model evaluates cars according to the following concept structure:\r\n\r\nCAR                      car acceptability\r\n. PRICE                  overall price\r\n. . buying               buying price\r\n. . maint                price of the maintenance\r\n. TECH                   technical characteristics\r\n. . COMFORT              comfort\r\n. . . doors              number of doors\r\n. . . persons            capacity in terms of persons to carry\r\n. . . lug_boot           the size of luggage boot\r\n. . safety               estimated safety of the car\r\n\r\nInput attributes are printed in lowercase. Besides the target concept (CAR), the model includes three intermediate concepts: PRICE, TECH, COMFORT. Every concept is in the original model related to its lower level descendants by a set of examples (for these examples sets see http://www-ai.ijs.si/BlazZupan/car.html).\r\n\r\nThe Car Evaluation Database contains examples with the structural information removed, i.e., directly relates CAR to the six input attributes: buying, maint, doors, persons, lug_boot, safety.\r\n\r\nBecause of known underlying concept structure, this database may be particularly useful for testing constructive induction and structure discovery methods.\r\n', 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': 'buying:   vhigh, high, med, low.\nmaint:    vhigh, high, med, low.\ndoors:    2, 3, 4, 5more.\npersons:  2, 4, more.\nlug_boot: small, med, big.\nsafety:   low, med, high.', 'citation': None}}
#        name     role         type demographic  \
# 0    buying  Feature  Categorical        None
# 1     maint  Feature  Categorical        None
# 2     doors  Feature  Categorical        None
# 3   persons  Feature  Categorical        None
# 4  lug_boot  Feature  Categorical        None
# 5    safety  Feature  Categorical        None
# 6     class   Target  Categorical        None
#
#                                          description units missing_values
# 0                                       buying price  None             no
# 1                           price of the maintenance  None             no
# 2                                    number of doors  None             no
# 3              capacity in terms of persons to carry  None             no
# 4                           the size of luggage boot  None             no
# 5                        estimated safety of the car  None             no
# 6  evaulation level (unacceptable, acceptable, go...  None             no

# %%
X.isnull()
# Out:
#       buying  maint  doors  persons  lug_boot  safety
# 0      False  False  False    False     False   False
# 1      False  False  False    False     False   False
# 2      False  False  False    False     False   False
# 3      False  False  False    False     False   False
# 4      False  False  False    False     False   False
# ...      ...    ...    ...      ...       ...     ...
# 1723   False  False  False    False     False   False
# 1724   False  False  False    False     False   False
# 1725   False  False  False    False     False   False
# 1726   False  False  False    False     False   False
# 1727   False  False  False    False     False   False
#
# [1728 rows x 6 columns]

# %%
y.isnull()
# Out:
#       class
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# ...     ...
# 1723  False
# 1724  False
# 1725  False
# 1726  False
# 1727  False
#
# [1728 rows x 1 columns]

# %%
X
# Out:
#      buying  maint  doors persons lug_boot safety
# 0     vhigh  vhigh      2       2    small    low
# 1     vhigh  vhigh      2       2    small    med
# 2     vhigh  vhigh      2       2    small   high
# 3     vhigh  vhigh      2       2      med    low
# 4     vhigh  vhigh      2       2      med    med
# ...     ...    ...    ...     ...      ...    ...
# 1723    low    low  5more    more      med    med
# 1724    low    low  5more    more      med   high
# 1725    low    low  5more    more      big    low
# 1726    low    low  5more    more      big    med
# 1727    low    low  5more    more      big   high
#
# [1728 rows x 6 columns]

# %%
y
# Out:
#       class
# 0     unacc
# 1     unacc
# 2     unacc
# 3     unacc
# 4     unacc
# ...     ...
# 1723   good
# 1724  vgood
# 1725  unacc
# 1726   good
# 1727  vgood
#
# [1728 rows x 1 columns]

# %%
import pandas as pd
df = pd.concat([X, y], axis=1)
df
# Out:
#      buying  maint  doors persons lug_boot safety  class
# 0     vhigh  vhigh      2       2    small    low  unacc
# 1     vhigh  vhigh      2       2    small    med  unacc
# 2     vhigh  vhigh      2       2    small   high  unacc
# 3     vhigh  vhigh      2       2      med    low  unacc
# 4     vhigh  vhigh      2       2      med    med  unacc
# ...     ...    ...    ...     ...      ...    ...    ...
# 1723    low    low  5more    more      med    med   good
# 1724    low    low  5more    more      med   high  vgood
# 1725    low    low  5more    more      big    low  unacc
# 1726    low    low  5more    more      big    med   good
# 1727    low    low  5more    more      big   high  vgood
#
# [1728 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Copy the original DataFrame
df_new = df.copy()

# Create a LabelEncoder object
label_encoder = LabelEncoder()

# Apply Label Encoding to each specified column
for column in ['buying',	'maint',	'doors',	'persons',	'lug_boot',	'safety',	'class']:
    df_new[column] = label_encoder.fit_transform(df_new[column])

df_new
# Out:
#       buying  maint  doors  persons  lug_boot  safety  class
# 0          3      3      0        0         2       1      2
# 1          3      3      0        0         2       2      2
# 2          3      3      0        0         2       0      2
# 3          3      3      0        0         1       1      2
# 4          3      3      0        0         1       2      2
# ...      ...    ...    ...      ...       ...     ...    ...
# 1723       1      1      3        2         1       2      1
# 1724       1      1      3        2         1       0      3
# 1725       1      1      3        2         0       1      2
# 1726       1      1      3        2         0       2      1
# 1727       1      1      3        2         0       0      3
#
# [1728 rows x 7 columns]

# %%
df_new.columns
# Out:
# Index(['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class'], dtype='object')

# %%
y = df_new['class']
X = df_new.drop(columns=['class'])

Yarr = y.to_numpy()
Xarr = X.to_numpy()

print("Shape of Y:", Yarr.shape)
print("Shape of X:", Xarr.shape)
# Out:
# Shape of Y: (1728,)
# Shape of X: (1728, 6)

# %%
import numpy as np

def shuffle_and_split_data(X, Y, test_ratio, val_ratio):
    # Shuffle indices
    shuffled_indices = np.random.permutation(len(X))
    
    # Calculate the sizes for test and validation sets
    test_set_size = int(len(X) * test_ratio)
    val_set_size = int(len(X) * val_ratio)
    
    # Get indices for each set
    test_indices = shuffled_indices[:test_set_size]
    val_indices = shuffled_indices[test_set_size:test_set_size + val_set_size]
    train_indices = shuffled_indices[test_set_size + val_set_size:]
    
    # Split the data
    return (X[train_indices], X[val_indices], X[test_indices], 
            Y[train_indices], Y[val_indices], Y[test_indices])

# %%
Xtrain_set, Xval_set, Xtest_set, Ytrain_set, Yval_set, Ytest_set = shuffle_and_split_data(Xarr, Yarr, test_ratio=0.15, val_ratio=0.15)

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# %%
import xgboost as xgb

# Prepare data for XGBoost
xgb_train = xgb.DMatrix(Xtrain_set, label=Ytrain_set, enable_categorical=True)
xgb_val = xgb.DMatrix(Xval_set, label=Yval_set, enable_categorical=True)
xgb_test = xgb.DMatrix(Xtest_set, label=Ytest_set , enable_categorical=True)

# Define XGBoost parameters for multi-class classification
num_classes = len(set(Ytrain_set))  # Automatically detect the number of classes

params = {
    'objective': 'multi:softmax',  # Use 'multi:softmax' for direct class prediction
    'eval_metric': 'mlogloss',     # Multi-class log loss
    'max_depth': 5,
    'learning_rate': 0.01,
    'n_estimators': 100,
    'num_class': num_classes        # Specify the number of classes
}

# Training with early stopping
bst = xgb.train(
    params,
    xgb_train,
    num_boost_round=500,            # Number of boosting rounds
    early_stopping_rounds=10,       # Early stopping using validation set
    evals=[(xgb_val, "validation")]
)

y_val_pred = bst.predict(xgb_val)
y_test_pred = bst.predict(xgb_test)
# Out:
# [0]	validation-mlogloss:1.37154
# [1]	validation-mlogloss:1.35708
# [2]	validation-mlogloss:1.34290
# [3]	validation-mlogloss:1.32900
# [4]	validation-mlogloss:1.31535
# [5]	validation-mlogloss:1.30190
# [6]	validation-mlogloss:1.28876
# [7]	validation-mlogloss:1.27591
# [8]	validation-mlogloss:1.26318
# [9]	validation-mlogloss:1.25079
# [10]	validation-mlogloss:1.23845
# [11]	validation-mlogloss:1.22656
# [12]	validation-mlogloss:1.21459
# [13]	validation-mlogloss:1.20303
# [14]	validation-mlogloss:1.19155
# [15]	validation-mlogloss:1.18017
# [16]	validation-mlogloss:1.16906
# [17]	validation-mlogloss:1.15814
# [18]	validation-mlogloss:1.14744
# [19]	validation-mlogloss:1.13677
# [20]	validation-mlogloss:1.12640
# [21]	validation-mlogloss:1.11606
# [22]	validation-mlogloss:1.10599
# [23]	validation-mlogloss:1.09597
# [24]	validation-mlogloss:1.08646
# [25]	validation-mlogloss:1.07684
# [26]	validation-mlogloss:1.06719
# [27]	validation-mlogloss:1.05799
# [28]	validation-mlogloss:1.04863
# [29]	validation-mlogloss:1.03970
# [30]	validation-mlogloss:1.03079
# [31]	validation-mlogloss:1.02194
# [32]	validation-mlogloss:1.01333
# [33]	validation-mlogloss:1.00461
# [34]	validation-mlogloss:0.99627
# [35]	validation-mlogloss:0.98767
# [36]	validation-mlogloss:0.97960
# [37]	validation-mlogloss:0.97158
# [38]	validation-mlogloss:0.96337
# [39]	validation-mlogloss:0.95557
# [40]	validation-mlogloss:0.94769
# [41]	validation-mlogloss:0.94011
# [42]	validation-mlogloss:0.93238
# [43]	validation-mlogloss:0.92499
# [44]	validation-mlogloss:0.91751
# [45]	validation-mlogloss:0.91036
# [46]	validation-mlogloss:0.90303
# [47]	validation-mlogloss:0.89607
# [48]	validation-mlogloss:0.88903
# [49]	validation-mlogloss:0.88225
# [50]	validation-mlogloss:0.87531
# [51]	validation-mlogloss:0.86869
# [52]	validation-mlogloss:0.86190
# [53]	validation-mlogloss:0.85537
# [54]	validation-mlogloss:0.84867
# [55]	validation-mlogloss:0.84234
# [56]	validation-mlogloss:0.83588
# [57]	validation-mlogloss:0.82963
# [58]	validation-mlogloss:0.82326
# [59]	validation-mlogloss:0.81711
# [60]	validation-mlogloss:0.81096
# [61]	validation-mlogloss:0.80497
# [62]	validation-mlogloss:0.79897
# [63]	validation-mlogloss:0.79310
# [64]	validation-mlogloss:0.78728
# [65]	validation-mlogloss:0.78157
# [66]	validation-mlogloss:0.77576
# [67]	validation-mlogloss:0.77029
# [68]	validation-mlogloss:0.76471
# [69]	validation-mlogloss:0.75927
# [70]	validation-mlogloss:0.75375
# [71]	validation-mlogloss:0.74851
# [72]	validation-mlogloss:0.74309
# [73]	validation-mlogloss:0.73776
# [74]	validation-mlogloss:0.73262
# [75]	validation-mlogloss:0.72750
# [76]	validation-mlogloss:0.72242
# [77]	validation-mlogloss:0.71728
# [78]	validation-mlogloss:0.71241
# [79]	validation-mlogloss:0.70741
# [80]	validation-mlogloss:0.70267
# [81]	validation-mlogloss:0.69778
# [82]	validation-mlogloss:0.69311
# [83]	validation-mlogloss:0.68834
# [84]	validation-mlogloss:0.68376
# [85]	validation-mlogloss:0.67910
# [86]	validation-mlogloss:0.67454
# [87]	validation-mlogloss:0.67010
# [88]	validation-mlogloss:0.66556
# [89]	validation-mlogloss:0.66124
# [90]	validation-mlogloss:0.65684
# [91]	validation-mlogloss:0.65262
# [92]	validation-mlogloss:0.64828
# [93]	validation-mlogloss:0.64418
# [94]	validation-mlogloss:0.63996
# [95]	validation-mlogloss:0.63592
# [96]	validation-mlogloss:0.63173
# [97]	validation-mlogloss:0.62770
# [98]	validation-mlogloss:0.62363
# [99]	validation-mlogloss:0.61965
# [100]	validation-mlogloss:0.61579
# [101]	validation-mlogloss:0.61188
# [102]	validation-mlogloss:0.60813
# [103]	validation-mlogloss:0.60425
# [104]	validation-mlogloss:0.60057
# [105]	validation-mlogloss:0.59683
# [106]	validation-mlogloss:0.59323
# [107]	validation-mlogloss:0.58950
# [108]	validation-mlogloss:0.58585
# [109]	validation-mlogloss:0.58233
# [110]	validation-mlogloss:0.57877
# [111]	validation-mlogloss:0.57535
# [112]	validation-mlogloss:0.57184
# C:\Users\User\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [20:11:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [113]	validation-mlogloss:0.56848
# [114]	validation-mlogloss:0.56500
# [115]	validation-mlogloss:0.56171
# [116]	validation-mlogloss:0.55837
# [117]	validation-mlogloss:0.55500
# [118]	validation-mlogloss:0.55181
# [119]	validation-mlogloss:0.54853
# [120]	validation-mlogloss:0.54540
# [121]	validation-mlogloss:0.54217
# [122]	validation-mlogloss:0.53902
# [123]	validation-mlogloss:0.53593
# [124]	validation-mlogloss:0.53291
# [125]	validation-mlogloss:0.52981
# [126]	validation-mlogloss:0.52672
# [127]	validation-mlogloss:0.52384
# [128]	validation-mlogloss:0.52085
# [129]	validation-mlogloss:0.51795
# [130]	validation-mlogloss:0.51502
# [131]	validation-mlogloss:0.51219
# [132]	validation-mlogloss:0.50928
# [133]	validation-mlogloss:0.50636
# [134]	validation-mlogloss:0.50345
# [135]	validation-mlogloss:0.50077
# [136]	validation-mlogloss:0.49795
# [137]	validation-mlogloss:0.49524
# [138]	validation-mlogloss:0.49251
# [139]	validation-mlogloss:0.48971
# [140]	validation-mlogloss:0.48707
# [141]	validation-mlogloss:0.48447
# [142]	validation-mlogloss:0.48185
# [143]	validation-mlogloss:0.47931
# [144]	validation-mlogloss:0.47646
# [145]	validation-mlogloss:0.47368
# [146]	validation-mlogloss:0.47087
# [147]	validation-mlogloss:0.46825
# [148]	validation-mlogloss:0.46551
# [149]	validation-mlogloss:0.46283
# [150]	validation-mlogloss:0.46015
# [151]	validation-mlogloss:0.45767
# [152]	validation-mlogloss:0.45504
# [153]	validation-mlogloss:0.45245
# [154]	validation-mlogloss:0.45003
# [155]	validation-mlogloss:0.44761
# [156]	validation-mlogloss:0.44509
# [157]	validation-mlogloss:0.44268
# [158]	validation-mlogloss:0.44023
# [159]	validation-mlogloss:0.43777
# [160]	validation-mlogloss:0.43535
# [161]	validation-mlogloss:0.43303
# [162]	validation-mlogloss:0.43065
# [163]	validation-mlogloss:0.42825
# [164]	validation-mlogloss:0.42600
# [165]	validation-mlogloss:0.42364
# [166]	validation-mlogloss:0.42134
# [167]	validation-mlogloss:0.41914
# [168]	validation-mlogloss:0.41688
# [169]	validation-mlogloss:0.41461
# [170]	validation-mlogloss:0.41264
# [171]	validation-mlogloss:0.41044
# [172]	validation-mlogloss:0.40835
# [173]	validation-mlogloss:0.40631
# [174]	validation-mlogloss:0.40421
# [175]	validation-mlogloss:0.40212
# [176]	validation-mlogloss:0.40015
# [177]	validation-mlogloss:0.39818
# [178]	validation-mlogloss:0.39615
# [179]	validation-mlogloss:0.39409
# [180]	validation-mlogloss:0.39223
# [181]	validation-mlogloss:0.39019
# [182]	validation-mlogloss:0.38822
# [183]	validation-mlogloss:0.38641
# [184]	validation-mlogloss:0.38446
# [185]	validation-mlogloss:0.38255
# [186]	validation-mlogloss:0.38092
# [187]	validation-mlogloss:0.37925
# [188]	validation-mlogloss:0.37738
# [189]	validation-mlogloss:0.37581
# [190]	validation-mlogloss:0.37413
# [191]	validation-mlogloss:0.37250
# [192]	validation-mlogloss:0.37067
# [193]	validation-mlogloss:0.36914
# [194]	validation-mlogloss:0.36752
# [195]	validation-mlogloss:0.36587
# [196]	validation-mlogloss:0.36409
# [197]	validation-mlogloss:0.36266
# [198]	validation-mlogloss:0.36091
# [199]	validation-mlogloss:0.35920
# [200]	validation-mlogloss:0.35779
# [201]	validation-mlogloss:0.35626
# [202]	validation-mlogloss:0.35460
# [203]	validation-mlogloss:0.35311
# [204]	validation-mlogloss:0.35160
# [205]	validation-mlogloss:0.35015
# [206]	validation-mlogloss:0.34877
# [207]	validation-mlogloss:0.34709
# [208]	validation-mlogloss:0.34547
# [209]	validation-mlogloss:0.34408
# [210]	validation-mlogloss:0.34260
# [211]	validation-mlogloss:0.34100
# [212]	validation-mlogloss:0.33961
# [213]	validation-mlogloss:0.33820
# [214]	validation-mlogloss:0.33687
# [215]	validation-mlogloss:0.33530
# [216]	validation-mlogloss:0.33394
# [217]	validation-mlogloss:0.33257
# [218]	validation-mlogloss:0.33117
# [219]	validation-mlogloss:0.32984
# [220]	validation-mlogloss:0.32854
# [221]	validation-mlogloss:0.32730
# [222]	validation-mlogloss:0.32583
# [223]	validation-mlogloss:0.32441
# [224]	validation-mlogloss:0.32313
# [225]	validation-mlogloss:0.32181
# [226]	validation-mlogloss:0.32064
# [227]	validation-mlogloss:0.31936
# [228]	validation-mlogloss:0.31818
# [229]	validation-mlogloss:0.31692
# [230]	validation-mlogloss:0.31578
# [231]	validation-mlogloss:0.31451
# [232]	validation-mlogloss:0.31337
# [233]	validation-mlogloss:0.31214
# [234]	validation-mlogloss:0.31100
# [235]	validation-mlogloss:0.30981
# [236]	validation-mlogloss:0.30864
# [237]	validation-mlogloss:0.30744
# [238]	validation-mlogloss:0.30638
# [239]	validation-mlogloss:0.30519
# [240]	validation-mlogloss:0.30404
# [241]	validation-mlogloss:0.30297
# [242]	validation-mlogloss:0.30178
# [243]	validation-mlogloss:0.30076
# [244]	validation-mlogloss:0.29962
# [245]	validation-mlogloss:0.29859
# [246]	validation-mlogloss:0.29747
# [247]	validation-mlogloss:0.29640
# [248]	validation-mlogloss:0.29529
# [249]	validation-mlogloss:0.29422
# [250]	validation-mlogloss:0.29326
# [251]	validation-mlogloss:0.29215
# [252]	validation-mlogloss:0.29120
# [253]	validation-mlogloss:0.29017
# [254]	validation-mlogloss:0.28917
# [255]	validation-mlogloss:0.28814
# [256]	validation-mlogloss:0.28715
# [257]	validation-mlogloss:0.28608
# [258]	validation-mlogloss:0.28498
# [259]	validation-mlogloss:0.28401
# [260]	validation-mlogloss:0.28301
# [261]	validation-mlogloss:0.28204
# [262]	validation-mlogloss:0.28102
# [263]	validation-mlogloss:0.28014
# [264]	validation-mlogloss:0.27910
# [265]	validation-mlogloss:0.27819
# [266]	validation-mlogloss:0.27720
# [267]	validation-mlogloss:0.27635
# [268]	validation-mlogloss:0.27533
# [269]	validation-mlogloss:0.27453
# [270]	validation-mlogloss:0.27352
# [271]	validation-mlogloss:0.27274
# [272]	validation-mlogloss:0.27184
# [273]	validation-mlogloss:0.27087
# [274]	validation-mlogloss:0.26999
# [275]	validation-mlogloss:0.26906
# [276]	validation-mlogloss:0.26827
# [277]	validation-mlogloss:0.26734
# [278]	validation-mlogloss:0.26658
# [279]	validation-mlogloss:0.26570
# [280]	validation-mlogloss:0.26474
# [281]	validation-mlogloss:0.26392
# [282]	validation-mlogloss:0.26311
# [283]	validation-mlogloss:0.26224
# [284]	validation-mlogloss:0.26143
# [285]	validation-mlogloss:0.26061
# [286]	validation-mlogloss:0.25982
# [287]	validation-mlogloss:0.25893
# [288]	validation-mlogloss:0.25823
# [289]	validation-mlogloss:0.25736
# [290]	validation-mlogloss:0.25662
# [291]	validation-mlogloss:0.25575
# [292]	validation-mlogloss:0.25499
# [293]	validation-mlogloss:0.25416
# [294]	validation-mlogloss:0.25344
# [295]	validation-mlogloss:0.25271
# [296]	validation-mlogloss:0.25198
# [297]	validation-mlogloss:0.25122
# [298]	validation-mlogloss:0.25046
# [299]	validation-mlogloss:0.24963
# [300]	validation-mlogloss:0.24891
# [301]	validation-mlogloss:0.24821
# [302]	validation-mlogloss:0.24743
# [303]	validation-mlogloss:0.24679
# [304]	validation-mlogloss:0.24598
# [305]	validation-mlogloss:0.24532
# [306]	validation-mlogloss:0.24452
# [307]	validation-mlogloss:0.24380
# [308]	validation-mlogloss:0.24312
# [309]	validation-mlogloss:0.24236
# [310]	validation-mlogloss:0.24167
# [311]	validation-mlogloss:0.24096
# [312]	validation-mlogloss:0.24029
# [313]	validation-mlogloss:0.23964
# [314]	validation-mlogloss:0.23888
# [315]	validation-mlogloss:0.23822
# [316]	validation-mlogloss:0.23746
# [317]	validation-mlogloss:0.23683
# [318]	validation-mlogloss:0.23615
# [319]	validation-mlogloss:0.23544
# [320]	validation-mlogloss:0.23469
# [321]	validation-mlogloss:0.23410
# [322]	validation-mlogloss:0.23342
# [323]	validation-mlogloss:0.23279
# [324]	validation-mlogloss:0.23204
# [325]	validation-mlogloss:0.23135
# [326]	validation-mlogloss:0.23067
# [327]	validation-mlogloss:0.23001
# [328]	validation-mlogloss:0.22934
# [329]	validation-mlogloss:0.22876
# [330]	validation-mlogloss:0.22807
# [331]	validation-mlogloss:0.22747
# [332]	validation-mlogloss:0.22682
# [333]	validation-mlogloss:0.22621
# [334]	validation-mlogloss:0.22556
# [335]	validation-mlogloss:0.22495
# [336]	validation-mlogloss:0.22438
# [337]	validation-mlogloss:0.22372
# [338]	validation-mlogloss:0.22318
# [339]	validation-mlogloss:0.22261
# [340]	validation-mlogloss:0.22199
# [341]	validation-mlogloss:0.22142
# [342]	validation-mlogloss:0.22080
# [343]	validation-mlogloss:0.22026
# [344]	validation-mlogloss:0.21967
# [345]	validation-mlogloss:0.21906
# [346]	validation-mlogloss:0.21848
# [347]	validation-mlogloss:0.21791
# [348]	validation-mlogloss:0.21733
# [349]	validation-mlogloss:0.21677
# [350]	validation-mlogloss:0.21622
# [351]	validation-mlogloss:0.21562
# [352]	validation-mlogloss:0.21507
# [353]	validation-mlogloss:0.21452
# [354]	validation-mlogloss:0.21394
# [355]	validation-mlogloss:0.21336
# [356]	validation-mlogloss:0.21283
# [357]	validation-mlogloss:0.21234
# [358]	validation-mlogloss:0.21181
# [359]	validation-mlogloss:0.21133
# [360]	validation-mlogloss:0.21084
# [361]	validation-mlogloss:0.21030
# [362]	validation-mlogloss:0.20974
# [363]	validation-mlogloss:0.20920
# [364]	validation-mlogloss:0.20864
# [365]	validation-mlogloss:0.20811
# [366]	validation-mlogloss:0.20758
# [367]	validation-mlogloss:0.20708
# [368]	validation-mlogloss:0.20659
# [369]	validation-mlogloss:0.20608
# [370]	validation-mlogloss:0.20555
# [371]	validation-mlogloss:0.20503
# [372]	validation-mlogloss:0.20453
# [373]	validation-mlogloss:0.20402
# [374]	validation-mlogloss:0.20351
# [375]	validation-mlogloss:0.20304
# [376]	validation-mlogloss:0.20253
# [377]	validation-mlogloss:0.20204
# [378]	validation-mlogloss:0.20153
# [379]	validation-mlogloss:0.20103
# [380]	validation-mlogloss:0.20057
# [381]	validation-mlogloss:0.20012
# [382]	validation-mlogloss:0.19964
# [383]	validation-mlogloss:0.19920
# [384]	validation-mlogloss:0.19872
# [385]	validation-mlogloss:0.19827
# [386]	validation-mlogloss:0.19783
# [387]	validation-mlogloss:0.19739
# [388]	validation-mlogloss:0.19694
# [389]	validation-mlogloss:0.19650
# [390]	validation-mlogloss:0.19604
# [391]	validation-mlogloss:0.19556
# [392]	validation-mlogloss:0.19510
# [393]	validation-mlogloss:0.19467
# [394]	validation-mlogloss:0.19421
# [395]	validation-mlogloss:0.19377
# [396]	validation-mlogloss:0.19334
# [397]	validation-mlogloss:0.19294
# [398]	validation-mlogloss:0.19249
# [399]	validation-mlogloss:0.19208
# [400]	validation-mlogloss:0.19168
# [401]	validation-mlogloss:0.19127
# [402]	validation-mlogloss:0.19086
# [403]	validation-mlogloss:0.19045
# [404]	validation-mlogloss:0.19005
# [405]	validation-mlogloss:0.18968
# [406]	validation-mlogloss:0.18929
# [407]	validation-mlogloss:0.18891
# [408]	validation-mlogloss:0.18848
# [409]	validation-mlogloss:0.18812
# [410]	validation-mlogloss:0.18779
# [411]	validation-mlogloss:0.18745
# [412]	validation-mlogloss:0.18709
# [413]	validation-mlogloss:0.18677
# [414]	validation-mlogloss:0.18643
# [415]	validation-mlogloss:0.18611
# [416]	validation-mlogloss:0.18578
# [417]	validation-mlogloss:0.18544
# [418]	validation-mlogloss:0.18514
# [419]	validation-mlogloss:0.18479
# [420]	validation-mlogloss:0.18447
# [421]	validation-mlogloss:0.18416
# [422]	validation-mlogloss:0.18383
# [423]	validation-mlogloss:0.18353
# [424]	validation-mlogloss:0.18322
# [425]	validation-mlogloss:0.18289
# [426]	validation-mlogloss:0.18260
# [427]	validation-mlogloss:0.18233
# [428]	validation-mlogloss:0.18201
# [429]	validation-mlogloss:0.18173
# [430]	validation-mlogloss:0.18141
# [431]	validation-mlogloss:0.18110
# [432]	validation-mlogloss:0.18081
# [433]	validation-mlogloss:0.18050
# [434]	validation-mlogloss:0.18027
# [435]	validation-mlogloss:0.17995
# [436]	validation-mlogloss:0.17966
# [437]	validation-mlogloss:0.17937
# [438]	validation-mlogloss:0.17907
# [439]	validation-mlogloss:0.17882
# [440]	validation-mlogloss:0.17854
# [441]	validation-mlogloss:0.17829
# [442]	validation-mlogloss:0.17802
# [443]	validation-mlogloss:0.17778
# [444]	validation-mlogloss:0.17748
# [445]	validation-mlogloss:0.17724
# [446]	validation-mlogloss:0.17695
# [447]	validation-mlogloss:0.17670
# [448]	validation-mlogloss:0.17648
# [449]	validation-mlogloss:0.17623
# [450]	validation-mlogloss:0.17601
# [451]	validation-mlogloss:0.17573
# [452]	validation-mlogloss:0.17551
# [453]	validation-mlogloss:0.17523
# [454]	validation-mlogloss:0.17494
# [455]	validation-mlogloss:0.17470
# [456]	validation-mlogloss:0.17445
# [457]	validation-mlogloss:0.17418
# [458]	validation-mlogloss:0.17393
# [459]	validation-mlogloss:0.17375
# [460]	validation-mlogloss:0.17348
# [461]	validation-mlogloss:0.17315
# [462]	validation-mlogloss:0.17284
# [463]	validation-mlogloss:0.17248
# [464]	validation-mlogloss:0.17221
# [465]	validation-mlogloss:0.17189
# [466]	validation-mlogloss:0.17166
# [467]	validation-mlogloss:0.17130
# [468]	validation-mlogloss:0.17106
# [469]	validation-mlogloss:0.17067
# [470]	validation-mlogloss:0.17040
# [471]	validation-mlogloss:0.17008
# [472]	validation-mlogloss:0.16980
# [473]	validation-mlogloss:0.16949
# [474]	validation-mlogloss:0.16922
# [475]	validation-mlogloss:0.16890
# [476]	validation-mlogloss:0.16869
# [477]	validation-mlogloss:0.16831
# [478]	validation-mlogloss:0.16810
# [479]	validation-mlogloss:0.16784
# [480]	validation-mlogloss:0.16750
# [481]	validation-mlogloss:0.16730
# [482]	validation-mlogloss:0.16706
# [483]	validation-mlogloss:0.16674
# [484]	validation-mlogloss:0.16645
# [485]	validation-mlogloss:0.16615
# [486]	validation-mlogloss:0.16592
# [487]	validation-mlogloss:0.16564
# [488]	validation-mlogloss:0.16543
# [489]	validation-mlogloss:0.16513
# [490]	validation-mlogloss:0.16477
# [491]	validation-mlogloss:0.16446
# [492]	validation-mlogloss:0.16428
# [493]	validation-mlogloss:0.16405
# [494]	validation-mlogloss:0.16374
# [495]	validation-mlogloss:0.16355
# [496]	validation-mlogloss:0.16320
# [497]	validation-mlogloss:0.16294
# [498]	validation-mlogloss:0.16274
# [499]	validation-mlogloss:0.16258

# %%
def accuracy(y_true, y_pred):
    TP, FP, TN, FN = confusion_matrix(y_true, y_pred)
    return (TP + TN) / (TP + TN + FP + FN)

# %%
def confusion_matrix(y_true, y_pred):
    TP = sum((y_true == 1) & (y_pred == 1))
    FP = sum((y_true == 0) & (y_pred == 1))
    TN = sum((y_true == 0) & (y_pred == 0))
    FN = sum((y_true == 1) & (y_pred == 0))
    return TP, FP, TN, FN

# %%
def precision(y_true, y_pred):
    TP, FP, TN, FN = confusion_matrix(y_true, y_pred)
    return TP / (TP + FP) if (TP + FP) != 0 else 0

# %%
def recall(y_true, y_pred):
    TP, FP, TN, FN = confusion_matrix(y_true, y_pred)
    return TP / (TP + FN) if (TP + FN) != 0 else 0

# %%
def f_score(y_true, y_pred):
    prec = precision(y_true, y_pred)
    rec = recall(y_true, y_pred)
    return 2 * (prec * rec) / (prec + rec) if (prec + rec) != 0 else 0

# %%
def average_precision(y_true, y_pred, class_labels):
    precision_vals = []
    for label in class_labels:
        # Create binary classification for the current class
        binary_true = (y_true == label).astype(int)
        binary_pred = (y_pred == label).astype(int)
        
        # Calculate precision and recall for this class
        prec = precision(binary_true, binary_pred)
        recall_val = recall(binary_true, binary_pred)
        
        # Store precision for the current class
        precision_vals.append(prec)
    
    return sum(precision_vals) / len(precision_vals)

# %%
def average_recall(y_true, y_pred, class_labels):
    recall_vals = []
    for label in class_labels:
        # Create binary classification for the current class
        binary_true = (y_true == label).astype(int)
        binary_pred = (y_pred == label).astype(int)
        
        # Calculate recall for this class
        recall_val = recall(binary_true, binary_pred)
        
        # Store recall for the current class
        recall_vals.append(recall_val)
    
    return sum(recall_vals) / len(recall_vals)

# %%
def average_f_score(y_true, y_pred, class_labels):
    fscore_vals = []
    for label in class_labels:
        # Create binary classification for the current class
        binary_true = (y_true == label).astype(int)
        binary_pred = (y_pred == label).astype(int)
        
        # Calculate F-score for this class
        fscore_val = f_score(binary_true, binary_pred)
        
        # Store F-score for the current class
        fscore_vals.append(fscore_val)
    
    return sum(fscore_vals) / len(fscore_vals)

# %%
class_labels = df_new['class'].unique()

print("Accuracy:", accuracy(Yval_set, y_val_pred))
TP, FP, TN, FN = confusion_matrix(Yval_set, y_val_pred)
print(f"Confusion Matrix:\nTP: {TP}, FP: {FP}, TN: {TN}, FN: {FN}")
print("Average Precision:", average_precision(Yval_set, y_val_pred, class_labels))
print("Average Recall:", average_recall(Yval_set, y_val_pred, class_labels))
print("Average F-score:", average_f_score(Yval_set, y_val_pred, class_labels))
# Out:
# Accuracy: 0.9259259259259259
# Confusion Matrix:
# TP: 4, FP: 2, TN: 71, FN: 4
# Average Precision: 0.8694083694083693
# Average Recall: 0.8619062849832081
# Average F-score: 0.8617625030144509
